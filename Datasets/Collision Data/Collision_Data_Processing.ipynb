# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import keplergl
#from keplergl import KeplerGL
import matplotlib as plt
import plotly.express as px
import dtale 
import h3
# Out:
# /Users/rakeenahmed/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#reading in data
collisions = gpd.read_file('All_Collisions.geojson')
ksi = gpd.read_file('KSI.geojson')

# %% [markdown]
# # All Collisions

# %%
collisions.head()
# Out:
#    OBJECTID   EventUniqueId            OccurrenceDate    Month Day_of_Week  \
# 0       401  GO-20148000204 2014-01-03 05:00:00+00:00  January      Friday
# 1       402  GO-20148000205 2014-01-03 05:00:00+00:00  January      Friday
# 2       403  GO-20148000206 2014-01-03 05:00:00+00:00  January      Friday
# 3       404  GO-20148000208 2014-01-03 05:00:00+00:00  January      Friday
# 4       405  GO-20148000209 2014-01-03 05:00:00+00:00  January      Friday
#
#    Year  Hour Division Atom          Neighbourhood  Fatalities  \
# 0  2014     8      NSA  NSA                    NSA           0
# 1  2014    12  D54/D55   68   North Riverdale (68)           0
# 2  2014     8      NSA  NSA                    NSA           0
# 3  2014    11      D52   79        University (79)           0
# 4  2014    13      D32   50  Newtonbrook East (50)           0
#
#   Injury_Collisions FTR_Collisions PD_Collisions  Longitude   Latitude  \
# 0                NO             NO           YES   0.000000   0.000000
# 1                NO             NO           YES -79.353893  43.670491
# 2                NO             NO           YES   0.000000   0.000000
# 3                NO             NO           YES -79.402070  43.663052
# 4                NO             NO           YES -79.420043  43.798000
#
#    ObjectId2                    geometry
# 0          1     POINT (0.00000 0.00000)
# 1          2  POINT (-79.35389 43.67049)
# 2          3     POINT (0.00000 0.00000)
# 3          4  POINT (-79.40207 43.66305)
# 4          5  POINT (-79.42004 43.79800)

# %%
#converting column headers to lowercase
collisions.columns = [s.strip().replace(' ','_').lower() for s in collisions.columns]

# %%
#shape of dataframe
collisions.shape
# Out:
# (553780, 18)

# %%
#checking column names
collisions.columns
# Out:
# Index(['objectid', 'eventuniqueid', 'occurrencedate', 'month', 'day_of_week',
#        'year', 'hour', 'division', 'atom', 'neighbourhood', 'fatalities',
#        'injury_collisions', 'ftr_collisions', 'pd_collisions', 'longitude',
#        'latitude', 'objectid2', 'geometry'],
#       dtype='object')

# %%
#dropping unneeded columns
collisions = collisions.drop(columns=['objectid','atom','objectid2','occurrencedate'])
collisions.head()
# Out:
#     eventuniqueid    month day_of_week  year  hour division  \
# 0  GO-20148000204  January      Friday  2014     8      NSA
# 1  GO-20148000205  January      Friday  2014    12  D54/D55
# 2  GO-20148000206  January      Friday  2014     8      NSA
# 3  GO-20148000208  January      Friday  2014    11      D52
# 4  GO-20148000209  January      Friday  2014    13      D32
#
#            neighbourhood  fatalities injury_collisions ftr_collisions  \
# 0                    NSA           0                NO             NO
# 1   North Riverdale (68)           0                NO             NO
# 2                    NSA           0                NO             NO
# 3        University (79)           0                NO             NO
# 4  Newtonbrook East (50)           0                NO             NO
#
#   pd_collisions  longitude   latitude                    geometry
# 0           YES   0.000000   0.000000     POINT (0.00000 0.00000)
# 1           YES -79.353893  43.670491  POINT (-79.35389 43.67049)
# 2           YES   0.000000   0.000000     POINT (0.00000 0.00000)
# 3           YES -79.402070  43.663052  POINT (-79.40207 43.66305)
# 4           YES -79.420043  43.798000  POINT (-79.42004 43.79800)

# %%
#we will only take data from year 2016 onwards, since that is the time period of our analysis
collisions.drop(collisions[collisions['year']<2016].index,inplace=True)

# %%
#checking for missing values
#no missing values in the dataset
collisions.isna().sum()
# Out:
# eventuniqueid        0
# month                0
# day_of_week          0
# year                 0
# hour                 0
# division             0
# neighbourhood        0
# fatalities           0
# injury_collisions    0
# ftr_collisions       0
# pd_collisions        0
# longitude            0
# latitude             0
# geometry             0
# dtype: int64

# %%
collisions.describe()
# Out:
#                 year           hour     fatalities      longitude  \
# count  421934.000000  421934.000000  421934.000000  421934.000000
# mean     2018.474209      13.440192       0.000927     -67.690507
# std         1.791188       4.979152       0.031197      28.145074
# min      2016.000000       0.000000       0.000000     -80.044952
# 25%      2017.000000      10.000000       0.000000     -79.448265
# 50%      2018.000000      14.000000       0.000000     -79.375178
# 75%      2020.000000      17.000000       0.000000     -79.267238
# max      2022.000000      23.000000       3.000000       0.000000
#
#             latitude
# count  421934.000000
# mean       37.271687
# std        15.497216
# min         0.000000
# 25%        43.647187
# 50%        43.697201
# 75%        43.755535
# max        44.435809

# %%
#checking how many collision rows have latitude and longitude = 0. i.e. are missing
collisions.latitude.where(collisions.longitude==0.000000).count()
# Out:
# 62192

# %%
#dropping rows with missing latitudes and longitudes
collisions.drop(collisions[collisions['latitude']==0].index,inplace=True)

# %%
#checking if rows were dropped from dataframe
collisions.shape
# Out:
# (359742, 14)

# %%
collisions.head()
# Out:
#          eventuniqueid    month day_of_week  year  hour division  \
# 131003  GO-20168000055  January      Friday  2016    16      D42
# 131004  GO-20168000056  January      Friday  2016    17  D54/D55
# 131005  GO-20168000057  January      Friday  2016    19      D41
# 131006  GO-20168000058  January      Friday  2016     3      D52
# 131007  GO-20168000059  January      Friday  2016     4      D41
#
#                       neighbourhood  fatalities injury_collisions  \
# 131003              LAmoreaux (117)           0                NO
# 131004       Woodbine Corridor (64)           0               YES
# 131005           Kennedy Park (124)           0                NO
# 131006     Bay Street Corridor (76)           0                NO
# 131007  Birchcliffe-Cliffside (122)           0                NO
#
#        ftr_collisions pd_collisions  longitude   latitude  \
# 131003             NO           YES -79.319271  43.795851
# 131004             NO            NO -79.320851  43.683944
# 131005            YES            NO -79.251653  43.732248
# 131006             NO           YES -79.385522  43.646053
# 131007             NO           YES -79.284020  43.680810
#
#                           geometry
# 131003  POINT (-79.31927 43.79585)
# 131004  POINT (-79.32085 43.68394)
# 131005  POINT (-79.25165 43.73225)
# 131006  POINT (-79.38552 43.64605)
# 131007  POINT (-79.28402 43.68081)

# %%
#resetting the index because dropping the rows messed up the index
collisions.reset_index(inplace=True,drop=True)
collisions.head()
# Out:
#     eventuniqueid    month day_of_week  year  hour division  \
# 0  GO-20168000055  January      Friday  2016    16      D42
# 1  GO-20168000056  January      Friday  2016    17  D54/D55
# 2  GO-20168000057  January      Friday  2016    19      D41
# 3  GO-20168000058  January      Friday  2016     3      D52
# 4  GO-20168000059  January      Friday  2016     4      D41
#
#                  neighbourhood  fatalities injury_collisions ftr_collisions  \
# 0              LAmoreaux (117)           0                NO             NO
# 1       Woodbine Corridor (64)           0               YES             NO
# 2           Kennedy Park (124)           0                NO            YES
# 3     Bay Street Corridor (76)           0                NO             NO
# 4  Birchcliffe-Cliffside (122)           0                NO             NO
#
#   pd_collisions  longitude   latitude                    geometry
# 0           YES -79.319271  43.795851  POINT (-79.31927 43.79585)
# 1            NO -79.320851  43.683944  POINT (-79.32085 43.68394)
# 2            NO -79.251653  43.732248  POINT (-79.25165 43.73225)
# 3           YES -79.385522  43.646053  POINT (-79.38552 43.64605)
# 4           YES -79.284020  43.680810  POINT (-79.28402 43.68081)

# %%
#setting eventuniqueid as index
collisions.set_index('eventuniqueid',inplace=True)

# %%
#creating a column to identify whether a collision resulted in fatalities. this will work as a flag

#first define function to create the labels for the new column
def fatal_collision_indicator(num_fatalities):
    if num_fatalities==0:
        return 'NO'
    elif num_fatalities>0:
        return 'YES'

#applying this function on the dataframe to create a new fatal_collision column
collisions['fatal_collisions'] = collisions['fatalities'].apply(fatal_collision_indicator)

# %%
#checking the values for the new columns created
collisions.fatal_collisions.value_counts()
# Out:
# NO     359366
# YES       376
# Name: fatal_collisions, dtype: int64

# %%
#looking at data types
collisions.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 359742 entries, GO-20168000055 to GO-20228022870
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   month              359742 non-null  object
#  1   day_of_week        359742 non-null  object
#  2   year               359742 non-null  int64
#  3   hour               359742 non-null  int64
#  4   division           359742 non-null  object
#  5   neighbourhood      359742 non-null  object
#  6   fatalities         359742 non-null  int64
#  7   injury_collisions  359742 non-null  object
#  8   ftr_collisions     359742 non-null  object
#  9   pd_collisions      359742 non-null  object
#  10  longitude          359742 non-null  float64
#  11  latitude           359742 non-null  float64
#  12  geometry           359742 non-null  geometry
#  13  fatal_collisions   359742 non-null  object
# dtypes: float64(2), geometry(1), int64(3), object(8)
# memory usage: 49.2+ MB

# %%
#we want to convert the latitude and longitude values to h3 hex cells

#first, we need to combine the latitude and longitude values into a coordinates column
#collisions['coordinates'] = collisions['latitude'].astype('str') + ',' + collisions['longitude'].astype('str')

#then we define the function to get h3 hex cells from coordinates data
#def get_hex_cell(coordinates):
    a = float(coordinates.split(',')[0])
    b = float(coordinates.split(',')[1])
    return h3.latlng_to_cell(a,b,res=10)

#finally, create a new column for hex cells by applying the function on coordinates column
#collisions['hex_cell'] = collisions['coordinates'].apply(get_hex_cell)
# Out:
#   Input In [89]
#     a = float(coordinates.split(',')[0])
#     ^
# IndentationError: unexpected indent

# %%
#number of unique hex cells created
#collisions.hex_cell.nunique()

# %%
#creating a column for times of day from the hour column
collisions['time_of_day'] = collisions['hour'].apply(lambda x: 'morning' if 5<=x<12 else 'afternoon' if 12<=x<17 else 'evening' if 17<=x<21 else 'night')

# %%
collisions.head()
# Out:
#                   month day_of_week  year  hour division  \
# eventuniqueid
# GO-20168000055  January      Friday  2016    16      D42
# GO-20168000056  January      Friday  2016    17  D54/D55
# GO-20168000057  January      Friday  2016    19      D41
# GO-20168000058  January      Friday  2016     3      D52
# GO-20168000059  January      Friday  2016     4      D41
#
#                               neighbourhood  fatalities injury_collisions  \
# eventuniqueid
# GO-20168000055              LAmoreaux (117)           0                NO
# GO-20168000056       Woodbine Corridor (64)           0               YES
# GO-20168000057           Kennedy Park (124)           0                NO
# GO-20168000058     Bay Street Corridor (76)           0                NO
# GO-20168000059  Birchcliffe-Cliffside (122)           0                NO
#
#                ftr_collisions pd_collisions  longitude   latitude  \
# eventuniqueid
# GO-20168000055             NO           YES -79.319271  43.795851
# GO-20168000056             NO            NO -79.320851  43.683944
# GO-20168000057            YES            NO -79.251653  43.732248
# GO-20168000058             NO           YES -79.385522  43.646053
# GO-20168000059             NO           YES -79.284020  43.680810
#
#                                   geometry fatal_collisions time_of_day
# eventuniqueid
# GO-20168000055  POINT (-79.31927 43.79585)               NO   afternoon
# GO-20168000056  POINT (-79.32085 43.68394)               NO     evening
# GO-20168000057  POINT (-79.25165 43.73225)               NO     evening
# GO-20168000058  POINT (-79.38552 43.64605)               NO       night
# GO-20168000059  POINT (-79.28402 43.68081)               NO       night

# %%
collisions.describe()
# Out:
#                 year           hour     fatalities      longitude  \
# count  359742.000000  359742.000000  359742.000000  359742.000000
# mean     2018.414981      13.483744       0.001067     -79.392805
# std         1.805922       4.977226       0.033495       0.101770
# min      2016.000000       0.000000       0.000000     -80.044952
# 25%      2017.000000      10.000000       0.000000     -79.464519
# 50%      2018.000000      14.000000       0.000000     -79.392814
# 75%      2020.000000      17.000000       0.000000     -79.315292
# max      2022.000000      23.000000       3.000000     -78.495607
#
#             latitude
# count  359742.000000
# mean       43.715196
# std         0.056100
# min        43.302551
# 25%        43.665824
# 50%        43.714087
# 75%        43.761509
# max        44.435809

# %%
#checking for skews 
#fatalities is the only column that is skewed. this is fixed by adding the fatal_collision boolean column earlier
collisions.fatalities.skew()
# Out:
# 33.63708848648862

# %%
#adding a column prefix for columns in the dataset
collisions.columns = ['collisions_' + s if s != 'geometry' else s for s in collisions.columns]

# %%
collisions.to_file('collisions_processed.geojson')

# %% [markdown]
# # KSI Data

# %%
ksi.head()
# Out:
#     INDEX_  ACCNUM  YEAR                      DATE TIME          STREET1  \
# 0  3387730  892658  2006 2006-03-11 05:00:00+00:00  852       BLOOR ST W
# 1  3387731  892658  2006 2006-03-11 05:00:00+00:00  852       BLOOR ST W
# 2  3388101  892810  2006 2006-03-11 05:00:00+00:00  915  MORNINGSIDE AVE
# 3  3389067  893184  2006 2006-01-01 05:00:00+00:00  236     WOODBINE AVE
# 4  3388102  892810  2006 2006-03-11 05:00:00+00:00  915  MORNINGSIDE AVE
#
#           STREET2 OFFSET      ROAD_CLASS               DISTRICT  ...  \
# 0     DUNDAS ST W    NaN  Major Arterial  Toronto and East York  ...
# 1     DUNDAS ST W    NaN  Major Arterial  Toronto and East York  ...
# 2  SHEPPARD AVE E    NaN  Major Arterial            Scarborough  ...
# 3     O CONNOR DR    NaN  Major Arterial  Toronto and East York  ...
# 4  SHEPPARD AVE E    NaN  Major Arterial            Scarborough  ...
#
#    REDLIGHT  ALCOHOL  DISABILITY HOOD_158 NEIGHBOURHOOD_158 HOOD_140  \
# 0       NaN      NaN         NaN       88   High Park North       88
# 1       NaN      NaN         NaN       88   High Park North       88
# 2       Yes      NaN         NaN      146      Malvern East      132
# 3       NaN      Yes         NaN       60  Woodbine-Lumsden       60
# 4       Yes      NaN         NaN      146      Malvern East      132
#
#        NEIGHBOURHOOD_140 DIVISION ObjectId                    geometry
# 0   High Park North (88)      D11        1  POINT (-79.45249 43.65635)
# 1   High Park North (88)      D11        2  POINT (-79.45249 43.65635)
# 2          Malvern (132)      D42        3  POINT (-79.19979 43.80194)
# 3  Woodbine-Lumsden (60)      D55        4  POINT (-79.31880 43.69960)
# 4          Malvern (132)      D42        5  POINT (-79.19979 43.80194)
#
# [5 rows x 56 columns]

# %%
ksi.columns
# Out:
# Index(['INDEX_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'STREET1', 'STREET2',
#        'OFFSET', 'ROAD_CLASS', 'DISTRICT', 'WARDNUM', 'LATITUDE', 'LONGITUDE',
#        'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND',
#        'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY', 'FATAL_NO',
#        'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDTYPE',
#        'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND', 'PEDESTRIAN',
#        'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH',
#        'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL',
#        'DISABILITY', 'HOOD_158', 'NEIGHBOURHOOD_158', 'HOOD_140',
#        'NEIGHBOURHOOD_140', 'DIVISION', 'ObjectId', 'geometry'],
#       dtype='object')

# %%
#convert column headers to lowercase, strip whitespace, replace spaces with underscore
ksi.columns = [s.strip().replace(' ','_').lower() for s in ksi.columns]

# %%
#renaming index column
ksi.rename(columns={'index_':'index'},inplace=True)

# %%
#dropping unneccesary columns
ksi = ksi.drop(columns = ['accnum','offset','fatal_no','initdir','hood_158','hood_140','neighbourhood_140','wardnum','objectid'])

# %%
#dropping rows with year before 2016
ksi.drop(ksi[ksi['year']<2016].index,inplace=True)

# %%
#resetting the index because dropping the rows messed up the index
ksi.reset_index(inplace=True,drop=True)
ksi.head()
# Out:
#       index  year                      date  time          street1  \
# 0  80566288  2016 2016-08-01 04:00:00+00:00   156  MORNINGSIDE AVE
# 1  80632072  2016 2016-08-02 04:00:00+00:00  1745       FRONT ST E
# 2  80632073  2016 2016-08-02 04:00:00+00:00  1745       FRONT ST E
# 3  80632074  2016 2016-08-02 04:00:00+00:00  2112    BLUE JAYS WAY
# 4  80632075  2016 2016-08-02 04:00:00+00:00  2112    BLUE JAYS WAY
#
#           street2      road_class               district   latitude  \
# 0     HALFWAY AVE  Minor Arterial            Scarborough  43.817847
# 1        YONGE ST  Major Arterial  Toronto and East York  43.646811
# 2        YONGE ST  Major Arterial  Toronto and East York  43.646811
# 3  NAVY WHARF CRT  Minor Arterial  Toronto and East York  43.641570
# 4  NAVY WHARF CRT  Minor Arterial  Toronto and East York  43.641570
#
#    longitude  ... emerg_veh passenger speeding ag_driv redlight alcohol  \
# 0 -79.213687  ...       NaN       Yes      NaN     Yes      NaN     NaN
# 1 -79.376933  ...       NaN       NaN      NaN     Yes      NaN     NaN
# 2 -79.376933  ...       NaN       NaN      NaN     Yes      NaN     NaN
# 3 -79.391864  ...       NaN       Yes      NaN     Yes      NaN     NaN
# 4 -79.391864  ...       NaN       Yes      NaN     Yes      NaN     NaN
#
#   disability                      neighbourhood_158 division  \
# 0        NaN                           Malvern East      D42
# 1        NaN  St Lawrence-East Bayfront-The Islands      D51
# 2        NaN  St Lawrence-East Bayfront-The Islands      D51
# 3        NaN                 Harbourfront-CityPlace      D52
# 4        NaN                 Harbourfront-CityPlace      D52
#
#                      geometry
# 0  POINT (-79.21369 43.81785)
# 1  POINT (-79.37693 43.64681)
# 2  POINT (-79.37693 43.64681)
# 3  POINT (-79.39186 43.64157)
# 4  POINT (-79.39186 43.64157)
#
# [5 rows x 47 columns]

# %%
#setting accnum as index
ksi.set_index('index',inplace=True)

# %%
ksi.shape
# Out:
# (5962, 46)

# %%
#checking for duplicate rows
ksi.duplicated().sum()
# Out:
# 115

# %%
#checking null values
ksi.isnull().sum()
# Out:
# index                   0
# year                    0
# date                    0
# time                    0
# street1                 0
# street2               607
# road_class             55
# district               96
# latitude                0
# longitude               0
# loccoord                5
# accloc                 10
# traffctl                5
# visibility             20
# light                   0
# rdsfcond               25
# acclass                 5
# impactype               4
# invtype                 9
# invage                  0
# injury                 12
# vehtype              2244
# manoeuver            2220
# drivact              2600
# drivcond             2601
# pedtype              4852
# pedact               4820
# pedcond              4813
# cyclistype           5691
# cycact               5685
# cyccond              5685
# pedestrian           3437
# cyclist              5351
# automobile            554
# motorcycle           5222
# truck                5617
# trsn_city_veh        5622
# emerg_veh            5932
# passenger            3500
# speeding             4898
# ag_driv              2704
# redlight             5502
# alcohol              5753
# disability           5841
# neighbourhood_158       0
# division                0
# dtype: int64

# %%
#filling null values with N/A
ksi.fillna('N/A',inplace=True)

# %%
#adding a column called intersection
ksi['intersection'] = ksi['street1'].str.cat(ksi['street2'],sep=',')

# %%
#converting date column to datetime data type
#ksi.date = ksi.date.astype('datetime64')

# %%
#only showing date in the date column, not the time
ksi['date'] = ksi['date'].dt.date

# %%
#converting time to integer data type
ksi['time'] = ksi['time'].astype('int')

# %%
#rounding the time column to the nearest hour segment
import math
ksi['time'] = [t // 100 + (1 if t % 100 >= 30 else 0) for t in ksi['time']]

# %%
#creating a column for times of day based on the hour column
ksi['time_of_day'] = ksi['time'].apply(lambda x: 'morning' if 5<=x<12 else 'afternoon' if 12<=x<17 else 'evening' if 17<=x<21 else 'night')

# %%
#we want to convert the latitude and longitude values to h3 hex cells

#drop the columns if they exist
#ksi.drop(columns=['coordinates','hex_cell'])

#first, we need to combine the latitude and longitude values into a coordinates column
#ksi['coordinates'] = ksi['latitude'].astype('str') + ',' + ksi['longitude'].astype('str')

#then we define the function to get h3 hex cells from coordinates data
#def get_hex_cell(coordinates):
    a = float(coordinates.split(',')[0])
    b = float(coordinates.split(',')[1])
    return h3.latlng_to_cell(a,b,res=10)

#finally, create a new column for hex cells by applying the function on coordinates column
#ksi['hex_cell'] = ksi['coordinates'].apply(get_hex_cell)
# Out:
#   Input In [142]
#     a = float(coordinates.split(',')[0])
#     ^
# IndentationError: unexpected indent

# %%
ksi.head()
# Out:
#           year        date  time          street1         street2  \
# index
# 80566288  2016  2016-08-01     2  MORNINGSIDE AVE     HALFWAY AVE
# 80632072  2016  2016-08-02    18       FRONT ST E        YONGE ST
# 80632073  2016  2016-08-02    18       FRONT ST E        YONGE ST
# 80632074  2016  2016-08-02    21    BLUE JAYS WAY  NAVY WHARF CRT
# 80632075  2016  2016-08-02    21    BLUE JAYS WAY  NAVY WHARF CRT
#
#               road_class               district   latitude  longitude  \
# index
# 80566288  Minor Arterial            Scarborough  43.817847 -79.213687
# 80632072  Major Arterial  Toronto and East York  43.646811 -79.376933
# 80632073  Major Arterial  Toronto and East York  43.646811 -79.376933
# 80632074  Minor Arterial  Toronto and East York  43.641570 -79.391864
# 80632075  Minor Arterial  Toronto and East York  43.641570 -79.391864
#
#               loccoord  ... speeding ag_driv redlight alcohol disability  \
# index                   ...
# 80566288  Intersection  ...      N/A     Yes      N/A     N/A        N/A
# 80632072  Intersection  ...      N/A     Yes      N/A     N/A        N/A
# 80632073  Intersection  ...      N/A     Yes      N/A     N/A        N/A
# 80632074  Intersection  ...      N/A     Yes      N/A     N/A        N/A
# 80632075  Intersection  ...      N/A     Yes      N/A     N/A        N/A
#
#                               neighbourhood_158 division  \
# index
# 80566288                           Malvern East      D42
# 80632072  St Lawrence-East Bayfront-The Islands      D51
# 80632073  St Lawrence-East Bayfront-The Islands      D51
# 80632074                 Harbourfront-CityPlace      D52
# 80632075                 Harbourfront-CityPlace      D52
#
#                             geometry                  intersection time_of_day
# index
# 80566288  POINT (-79.21369 43.81785)   MORNINGSIDE AVE,HALFWAY AVE       night
# 80632072  POINT (-79.37693 43.64681)           FRONT ST E,YONGE ST     evening
# 80632073  POINT (-79.37693 43.64681)           FRONT ST E,YONGE ST     evening
# 80632074  POINT (-79.39186 43.64157)  BLUE JAYS WAY,NAVY WHARF CRT       night
# 80632075  POINT (-79.39186 43.64157)  BLUE JAYS WAY,NAVY WHARF CRT       night
#
# [5 rows x 48 columns]

# %%
ksi.index.duplicated().sum()
# Out:
# 0

# %%
ksi.describe()
# Out:
#               year         time     latitude    longitude
# count  5962.000000  5962.000000  5962.000000  5962.000000
# mean   2018.653304    14.235156    43.711171   -79.396253
# std       1.954197     6.378966     0.057434     0.106259
# min    2016.000000     0.000000    43.589678   -79.633502
# 25%    2017.000000    10.000000    43.659791   -79.476459
# 50%    2018.000000    15.000000    43.706267   -79.399108
# 75%    2020.000000    19.000000    43.757796   -79.318286
# max    2022.000000    24.000000    43.848780   -79.122974

# %%
#adding a column prefix for columns in the dataset
ksi.columns = ['ksi_' + s if s != 'geometry' else s for s in ksi.columns]

# %%
ksi.to_csv('ksi_processed.csv')
