# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import keplergl
#from keplergl import KeplerGL
import matplotlib as plt
import plotly.express as px
import dtale 
import h3
# Out:
# /Users/rakeenahmed/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#reading in data
collisions = pd.read_csv('All_Collisions.csv')
ksi = pd.read_csv('KSI.csv')

# %% [markdown]
# # All Collisions

# %%
collisions.head()
# Out:
#               X             Y  OBJECTID   EventUniqueId  \
# 0  0.000000e+00  0.000000e+00       401  GO-20148000204
# 1 -8.833635e+06  5.414591e+06       402  GO-20148000205
# 2  0.000000e+00  0.000000e+00       403  GO-20148000206
# 3 -8.838998e+06  5.413446e+06       404  GO-20148000208
# 4 -8.840999e+06  5.434235e+06       405  GO-20148000209
#
#            OccurrenceDate    Month Day_of_Week  Year  Hour Division Atom  \
# 0  2014/01/03 05:00:00+00  January      Friday  2014     8      NSA  NSA
# 1  2014/01/03 05:00:00+00  January      Friday  2014    12  D54/D55   68
# 2  2014/01/03 05:00:00+00  January      Friday  2014     8      NSA  NSA
# 3  2014/01/03 05:00:00+00  January      Friday  2014    11      D52   79
# 4  2014/01/03 05:00:00+00  January      Friday  2014    13      D32   50
#
#            Neighbourhood  Fatalities Injury_Collisions FTR_Collisions  \
# 0                    NSA           0                NO             NO
# 1   North Riverdale (68)           0                NO             NO
# 2                    NSA           0                NO             NO
# 3        University (79)           0                NO             NO
# 4  Newtonbrook East (50)           0                NO             NO
#
#   PD_Collisions  Longitude   Latitude  ObjectId2
# 0           YES   0.000000   0.000000          1
# 1           YES -79.353893  43.670491          2
# 2           YES   0.000000   0.000000          3
# 3           YES -79.402070  43.663052          4
# 4           YES -79.420043  43.798000          5

# %%
#converting column headers to lowercase
collisions.columns = [s.strip().replace(' ','_').lower() for s in collisions.columns]

# %%
#shape of dataframe
collisions.shape
# Out:
# (553780, 19)

# %%
#checking column names
collisions.columns
# Out:
# Index(['x', 'y', 'objectid', 'eventuniqueid', 'occurrencedate', 'month',
#        'day_of_week', 'year', 'hour', 'division', 'atom', 'neighbourhood',
#        'fatalities', 'injury_collisions', 'ftr_collisions', 'pd_collisions',
#        'longitude', 'latitude', 'objectid2'],
#       dtype='object')

# %%
#dropping unneeded columns
collisions = collisions.drop(columns=['x','y','objectid','atom','objectid2','occurrencedate'])
collisions.head()
# Out:
#     eventuniqueid    month day_of_week  year  hour division  \
# 0  GO-20148000204  January      Friday  2014     8      NSA
# 1  GO-20148000205  January      Friday  2014    12  D54/D55
# 2  GO-20148000206  January      Friday  2014     8      NSA
# 3  GO-20148000208  January      Friday  2014    11      D52
# 4  GO-20148000209  January      Friday  2014    13      D32
#
#            neighbourhood  fatalities injury_collisions ftr_collisions  \
# 0                    NSA           0                NO             NO
# 1   North Riverdale (68)           0                NO             NO
# 2                    NSA           0                NO             NO
# 3        University (79)           0                NO             NO
# 4  Newtonbrook East (50)           0                NO             NO
#
#   pd_collisions  longitude   latitude
# 0           YES   0.000000   0.000000
# 1           YES -79.353893  43.670491
# 2           YES   0.000000   0.000000
# 3           YES -79.402070  43.663052
# 4           YES -79.420043  43.798000

# %%
#we will only take data from year 2016 onwards, since that is the time period of our analysis
collisions.drop(collisions[collisions['year']<2016].index,inplace=True)

# %%
#checking for missing values
#no missing values in the dataset
collisions.isna().sum()
# Out:
# eventuniqueid        0
# month                0
# day_of_week          0
# year                 0
# hour                 0
# division             0
# neighbourhood        0
# fatalities           0
# injury_collisions    0
# ftr_collisions       0
# pd_collisions        0
# longitude            0
# latitude             0
# dtype: int64

# %%
collisions.describe()
# Out:
#                 year           hour     fatalities      longitude  \
# count  421934.000000  421934.000000  421934.000000  421934.000000
# mean     2018.474209      13.440192       0.000927     -67.690507
# std         1.791188       4.979152       0.031197      28.145074
# min      2016.000000       0.000000       0.000000     -80.044952
# 25%      2017.000000      10.000000       0.000000     -79.448265
# 50%      2018.000000      14.000000       0.000000     -79.375178
# 75%      2020.000000      17.000000       0.000000     -79.267238
# max      2022.000000      23.000000       3.000000       0.000000
#
#             latitude
# count  421934.000000
# mean       37.271687
# std        15.497216
# min         0.000000
# 25%        43.647187
# 50%        43.697201
# 75%        43.755535
# max        44.435809

# %%
#checking how many collision rows have latitude and longitude = 0. i.e. are missing
collisions.latitude.where(collisions.longitude==0.000000).count()
# Out:
# 62192

# %%
#dropping rows with missing latitudes and longitudes
collisions.drop(collisions[collisions['latitude']==0].index,inplace=True)

# %%
#checking if rows were dropped from dataframe
collisions.shape
# Out:
# (359742, 13)

# %%
collisions.head()
# Out:
#          eventuniqueid    month day_of_week  year  hour division  \
# 131003  GO-20168000055  January      Friday  2016    16      D42
# 131004  GO-20168000056  January      Friday  2016    17  D54/D55
# 131005  GO-20168000057  January      Friday  2016    19      D41
# 131006  GO-20168000058  January      Friday  2016     3      D52
# 131007  GO-20168000059  January      Friday  2016     4      D41
#
#                       neighbourhood  fatalities injury_collisions  \
# 131003              LAmoreaux (117)           0                NO
# 131004       Woodbine Corridor (64)           0               YES
# 131005           Kennedy Park (124)           0                NO
# 131006     Bay Street Corridor (76)           0                NO
# 131007  Birchcliffe-Cliffside (122)           0                NO
#
#        ftr_collisions pd_collisions  longitude   latitude
# 131003             NO           YES -79.319271  43.795851
# 131004             NO            NO -79.320851  43.683944
# 131005            YES            NO -79.251653  43.732248
# 131006             NO           YES -79.385522  43.646053
# 131007             NO           YES -79.284020  43.680810

# %%
#resetting the index because dropping the rows messed up the index
collisions.reset_index(inplace=True,drop=True)
collisions.head()
# Out:
#     eventuniqueid    month day_of_week  year  hour division  \
# 0  GO-20168000055  January      Friday  2016    16      D42
# 1  GO-20168000056  January      Friday  2016    17  D54/D55
# 2  GO-20168000057  January      Friday  2016    19      D41
# 3  GO-20168000058  January      Friday  2016     3      D52
# 4  GO-20168000059  January      Friday  2016     4      D41
#
#                  neighbourhood  fatalities injury_collisions ftr_collisions  \
# 0              LAmoreaux (117)           0                NO             NO
# 1       Woodbine Corridor (64)           0               YES             NO
# 2           Kennedy Park (124)           0                NO            YES
# 3     Bay Street Corridor (76)           0                NO             NO
# 4  Birchcliffe-Cliffside (122)           0                NO             NO
#
#   pd_collisions  longitude   latitude
# 0           YES -79.319271  43.795851
# 1            NO -79.320851  43.683944
# 2            NO -79.251653  43.732248
# 3           YES -79.385522  43.646053
# 4           YES -79.284020  43.680810

# %%
#creating a column to identify whether a collision resulted in fatalities. this will work as a flag

#first define function to create the labels for the new column
def fatal_collision_indicator(num_fatalities):
    if num_fatalities==0:
        return 'NO'
    elif num_fatalities>0:
        return 'YES'

#applying this function on the dataframe to create a new fatal_collision column
collisions['fatal_collisions'] = collisions['fatalities'].apply(fatal_collision_indicator)

# %%
#checking the values for the new columns created
collisions.fatal_collisions.value_counts()
# Out:
# NO     359366
# YES       376
# Name: fatal_collisions, dtype: int64

# %%
#looking at data types
collisions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359742 entries, 0 to 359741
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   eventuniqueid      359742 non-null  object
#  1   month              359742 non-null  object
#  2   day_of_week        359742 non-null  object
#  3   year               359742 non-null  int64
#  4   hour               359742 non-null  int64
#  5   division           359742 non-null  object
#  6   neighbourhood      359742 non-null  object
#  7   fatalities         359742 non-null  int64
#  8   injury_collisions  359742 non-null  object
#  9   ftr_collisions     359742 non-null  object
#  10  pd_collisions      359742 non-null  object
#  11  longitude          359742 non-null  float64
#  12  latitude           359742 non-null  float64
#  13  fatal_collisions   359742 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 38.4+ MB

# %%
#we want to convert the latitude and longitude values to h3 hex cells

#first, we need to combine the latitude and longitude values into a coordinates column
collisions['coordinates'] = collisions['latitude'].astype('str') + ',' + collisions['longitude'].astype('str')

#then we define the function to get h3 hex cells from coordinates data
def get_hex_cell(coordinates):
    a = float(coordinates.split(',')[0])
    b = float(coordinates.split(',')[1])
    return h3.latlng_to_cell(a,b,res=10)

#finally, create a new column for hex cells by applying the function on coordinates column
collisions['hex_cell'] = collisions['coordinates'].apply(get_hex_cell)

# %%
#number of unique hex cells created
collisions.hex_cell.nunique()
# Out:
# 17135

# %%
#creating a column for times of day from the hour column
collisions['time_of_day'] = collisions['hour'].apply(lambda x: 'morning' if 5<=x<12 else 'afternoon' if 12<=x<17 else 'evening' if 17<=x<21 else 'night')

# %%
collisions.head()
# Out:
#     eventuniqueid    month day_of_week  year  hour division  \
# 0  GO-20168000055  January      Friday  2016    16      D42
# 1  GO-20168000056  January      Friday  2016    17  D54/D55
# 2  GO-20168000057  January      Friday  2016    19      D41
# 3  GO-20168000058  January      Friday  2016     3      D52
# 4  GO-20168000059  January      Friday  2016     4      D41
#
#                  neighbourhood  fatalities injury_collisions ftr_collisions  \
# 0              LAmoreaux (117)           0                NO             NO
# 1       Woodbine Corridor (64)           0               YES             NO
# 2           Kennedy Park (124)           0                NO            YES
# 3     Bay Street Corridor (76)           0                NO             NO
# 4  Birchcliffe-Cliffside (122)           0                NO             NO
#
#   pd_collisions  longitude   latitude fatal_collisions  \
# 0           YES -79.319271  43.795851               NO
# 1            NO -79.320851  43.683944               NO
# 2            NO -79.251653  43.732248               NO
# 3           YES -79.385522  43.646053               NO
# 4           YES -79.284020  43.680810               NO
#
#                 coordinates         hex_cell time_of_day
# 0  43.79585129,-79.31927061  8b2b9bd7364afff   afternoon
# 1  43.68394391,-79.32085134  8b2b9bc66305fff     evening
# 2  43.73224777,-79.25165261  8b2b9bd4c4ddfff     evening
# 3  43.64605338,-79.38552201  8b2b9bc4601cfff       night
# 4  43.68081049,-79.28402002  8b2b9bc65c81fff       night

# %%
collisions.describe()
# Out:
#                 year           hour     fatalities      longitude  \
# count  359742.000000  359742.000000  359742.000000  359742.000000
# mean     2018.414981      13.483744       0.001067     -79.392805
# std         1.805922       4.977226       0.033495       0.101770
# min      2016.000000       0.000000       0.000000     -80.044952
# 25%      2017.000000      10.000000       0.000000     -79.464519
# 50%      2018.000000      14.000000       0.000000     -79.392814
# 75%      2020.000000      17.000000       0.000000     -79.315292
# max      2022.000000      23.000000       3.000000     -78.495607
#
#             latitude
# count  359742.000000
# mean       43.715196
# std         0.056100
# min        43.302551
# 25%        43.665824
# 50%        43.714087
# 75%        43.761509
# max        44.435809

# %%
#checking for skews 
#fatalities is the only column that is skewed. this is fixed by adding the fatal_collision boolean column earlier
collisions.skew()
# Out:
# C:\Users\arara\AppData\Local\Temp\ipykernel_27596\1789526453.py:3: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# year           0.360431
# hour          -0.417705
# fatalities    33.637088
# longitude     -0.011680
# latitude       0.151831
# dtype: float64

# %% [markdown]
# # KSI Data

# %%
ksi.head()
# Out:
#               X             Y   INDEX_    ACCNUM  YEAR  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658.0  2006
# 1 -8.844611e+06  5.412414e+06  3387731  892658.0  2006
# 2 -8.816480e+06  5.434843e+06  3388101  892810.0  2006
# 3 -8.829728e+06  5.419071e+06  3389067  893184.0  2006
# 4 -8.816480e+06  5.434843e+06  3388102  892810.0  2006
#
#                      DATE  TIME          STREET1         STREET2 OFFSET  ...  \
# 0  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 1  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 2  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
# 3  2006/01/01 05:00:00+00   236     WOODBINE AVE     O CONNOR DR    NaN  ...
# 4  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
#
#   AG_DRIV REDLIGHT  ALCOHOL  DISABILITY  HOOD_158 NEIGHBOURHOOD_158 HOOD_140  \
# 0     Yes      NaN      NaN         NaN        88   High Park North       88
# 1     Yes      NaN      NaN         NaN        88   High Park North       88
# 2     Yes      Yes      NaN         NaN       146      Malvern East      132
# 3     Yes      NaN      Yes         NaN        60  Woodbine-Lumsden       60
# 4     Yes      Yes      NaN         NaN       146      Malvern East      132
#
#        NEIGHBOURHOOD_140 DIVISION ObjectId
# 0   High Park North (88)      D11        1
# 1   High Park North (88)      D11        2
# 2          Malvern (132)      D42        3
# 3  Woodbine-Lumsden (60)      D55        4
# 4          Malvern (132)      D42        5
#
# [5 rows x 57 columns]

# %%
ksi.columns
# Out:
# Index(['X', 'Y', 'INDEX_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'DISTRICT', 'WARDNUM', 'LATITUDE',
#        'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT',
#        'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY',
#        'FATAL_NO', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND',
#        'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND',
#        'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV',
#        'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'HOOD_158', 'NEIGHBOURHOOD_158',
#        'HOOD_140', 'NEIGHBOURHOOD_140', 'DIVISION', 'ObjectId'],
#       dtype='object')

# %%
#convert column headers to lowercase, strip whitespace, replace spaces with underscore
ksi.columns = [s.strip().replace(' ','_').lower() for s in ksi.columns]

# %%
#renaming index column
ksi.rename(columns={'index_':'index'},inplace=True)

# %%
#dropping unneccesary columns
ksi = ksi.drop(columns = ['x','y','accnum','offset','fatal_no','initdir','hood_158','hood_140','neighbourhood_140','wardnum','objectid'])

# %%
#dropping rows with year before 2016
ksi.drop(ksi[ksi['year']<2016].index,inplace=True)

# %%
#resetting the index because dropping the rows messed up the index
ksi.reset_index(inplace=True,drop=True)
ksi.head()
# Out:
#       index  year                    date  time          street1  \
# 0  80566288  2016  2016/08/01 04:00:00+00   156  MORNINGSIDE AVE
# 1  80632072  2016  2016/08/02 04:00:00+00  1745       FRONT ST E
# 2  80632073  2016  2016/08/02 04:00:00+00  1745       FRONT ST E
# 3  80632074  2016  2016/08/02 04:00:00+00  2112    BLUE JAYS WAY
# 4  80632075  2016  2016/08/02 04:00:00+00  2112    BLUE JAYS WAY
#
#           street2      road_class               district   latitude  \
# 0     HALFWAY AVE  Minor Arterial            Scarborough  43.817847
# 1        YONGE ST  Major Arterial  Toronto and East York  43.646811
# 2        YONGE ST  Major Arterial  Toronto and East York  43.646811
# 3  NAVY WHARF CRT  Minor Arterial  Toronto and East York  43.641570
# 4  NAVY WHARF CRT  Minor Arterial  Toronto and East York  43.641570
#
#    longitude  ... trsn_city_veh emerg_veh passenger speeding ag_driv redlight  \
# 0 -79.213687  ...           Yes       NaN       Yes      NaN     Yes      NaN
# 1 -79.376933  ...           NaN       NaN       NaN      NaN     Yes      NaN
# 2 -79.376933  ...           NaN       NaN       NaN      NaN     Yes      NaN
# 3 -79.391864  ...           NaN       NaN       Yes      NaN     Yes      NaN
# 4 -79.391864  ...           NaN       NaN       Yes      NaN     Yes      NaN
#
#   alcohol disability                      neighbourhood_158 division
# 0     NaN        NaN                           Malvern East      D42
# 1     NaN        NaN  St Lawrence-East Bayfront-The Islands      D51
# 2     NaN        NaN  St Lawrence-East Bayfront-The Islands      D51
# 3     NaN        NaN                 Harbourfront-CityPlace      D52
# 4     NaN        NaN                 Harbourfront-CityPlace      D52
#
# [5 rows x 46 columns]

# %%
ksi.shape
# Out:
# (5962, 46)

# %%
#checking for duplicate rows
ksi.duplicated().sum()
# Out:
# 0

# %%
#checking null values
ksi.isnull().sum()
# Out:
# index                   0
# year                    0
# date                    0
# time                    0
# street1                 0
# street2               607
# road_class             55
# district               96
# latitude                0
# longitude               0
# loccoord                5
# accloc                 10
# traffctl                5
# visibility             20
# light                   0
# rdsfcond               25
# acclass                 5
# impactype               4
# invtype                 9
# invage                  0
# injury                 12
# vehtype              2244
# manoeuver            2220
# drivact              2600
# drivcond             2601
# pedtype              4852
# pedact               4820
# pedcond              4813
# cyclistype           5691
# cycact               5685
# cyccond              5685
# pedestrian           3437
# cyclist              5351
# automobile            554
# motorcycle           5222
# truck                5617
# trsn_city_veh        5622
# emerg_veh            5932
# passenger            3500
# speeding             4898
# ag_driv              2704
# redlight             5502
# alcohol              5753
# disability           5841
# neighbourhood_158       0
# division                0
# dtype: int64

# %%
#filling null values with N/A
ksi.fillna('N/A',inplace=True)

# %%
#adding a column called intersection
ksi['intersection'] = ksi['street1'].str.cat(ksi['street2'],sep=',')

# %%
#converting date column to datetime data type
ksi.date = ksi.date.astype('datetime64')

# %%
#only showing date in the date column, not the time
ksi['date'] = ksi['date'].dt.date

# %%
#rounding the time column to the nearest hour segment
import math
ksi['time'] = [t // 100 + (1 if t % 100 >= 30 else 0) for t in ksi['time']]

# %%
#creating a column for times of day based on the hour column
ksi['time_of_day'] = ksi['time'].apply(lambda x: 'morning' if 5<=x<12 else 'afternoon' if 12<=x<17 else 'evening' if 17<=x<21 else 'night')

# %%
#we want to convert the latitude and longitude values to h3 hex cells

#drop the columns if they exist
ksi.drop(columns=['coordinates','hex_cell'])

#first, we need to combine the latitude and longitude values into a coordinates column
ksi['coordinates'] = ksi['latitude'].astype('str') + ',' + ksi['longitude'].astype('str')

#then we define the function to get h3 hex cells from coordinates data
def get_hex_cell(coordinates):
    a = float(coordinates.split(',')[0])
    b = float(coordinates.split(',')[1])
    return h3.latlng_to_cell(a,b,res=10)

#finally, create a new column for hex cells by applying the function on coordinates column
ksi['hex_cell'] = ksi['coordinates'].apply(get_hex_cell)

# %%
ksi.head()
# Out:
#       index  year        date  time          street1         street2  \
# 0  80566288  2016  2016-08-01     2  MORNINGSIDE AVE     HALFWAY AVE
# 1  80632072  2016  2016-08-02    18       FRONT ST E        YONGE ST
# 2  80632073  2016  2016-08-02    18       FRONT ST E        YONGE ST
# 3  80632074  2016  2016-08-02    21    BLUE JAYS WAY  NAVY WHARF CRT
# 4  80632075  2016  2016-08-02    21    BLUE JAYS WAY  NAVY WHARF CRT
#
#        road_class               district   latitude  longitude  ... passenger  \
# 0  Minor Arterial            Scarborough  43.817847 -79.213687  ...       Yes
# 1  Major Arterial  Toronto and East York  43.646811 -79.376933  ...       N/A
# 2  Major Arterial  Toronto and East York  43.646811 -79.376933  ...       N/A
# 3  Minor Arterial  Toronto and East York  43.641570 -79.391864  ...       Yes
# 4  Minor Arterial  Toronto and East York  43.641570 -79.391864  ...       Yes
#
#   speeding ag_driv redlight alcohol disability  \
# 0      N/A     Yes      N/A     N/A        N/A
# 1      N/A     Yes      N/A     N/A        N/A
# 2      N/A     Yes      N/A     N/A        N/A
# 3      N/A     Yes      N/A     N/A        N/A
# 4      N/A     Yes      N/A     N/A        N/A
#
#                        neighbourhood_158 division  \
# 0                           Malvern East      D42
# 1  St Lawrence-East Bayfront-The Islands      D51
# 2  St Lawrence-East Bayfront-The Islands      D51
# 3                 Harbourfront-CityPlace      D52
# 4                 Harbourfront-CityPlace      D52
#
#                    intersection time_of_day
# 0   MORNINGSIDE AVE,HALFWAY AVE       night
# 1           FRONT ST E,YONGE ST     evening
# 2           FRONT ST E,YONGE ST     evening
# 3  BLUE JAYS WAY,NAVY WHARF CRT       night
# 4  BLUE JAYS WAY,NAVY WHARF CRT       night
#
# [5 rows x 48 columns]

# %%
ksi.index.duplicated().sum()
# Out:
# 0

# %%
ksi.describe()
# Out:
#               index         year         time     latitude    longitude
# count  5.962000e+03  5962.000000  5962.000000  5962.000000  5962.000000
# mean   8.114601e+07  2018.653304    14.235156    43.711171   -79.396253
# std    3.832150e+05     1.954197     6.378966     0.057434     0.106259
# min    8.000008e+07  2016.000000     0.000000    43.589678   -79.633502
# 25%    8.078403e+07  2017.000000    10.000000    43.659791   -79.476459
# 50%    8.113414e+07  2018.000000    15.000000    43.706267   -79.399108
# 75%    8.150960e+07  2020.000000    19.000000    43.757796   -79.318286
# max    8.170606e+07  2022.000000    24.000000    43.848780   -79.122974

# %%
#checking for skews
ksi.skew()
# Out:
# /var/folders/sv/rf_t3py91vj8qdm_n4yljrp40000gn/T/ipykernel_19223/3201729259.py:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# index       -0.101749
# year         0.278481
# time        -0.558438
# latitude     0.214206
# longitude    0.073801
# dtype: float64
